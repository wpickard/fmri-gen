# %% [markdown]
# # OpenNeuro Download
#
# OpenNeuro has documentation for how to do this with AWS CLI.
#
# Also see:
# https://lukas-snoek.com/NI-edu/fMRI-pattern-analysis/week_3/rsa.html

# %%
dataset_path = '/s/babbage/b/nobackup/nblancha/public-datasets/bold5000'

# %% [markdown]
# # Retrieve ROIs

# %%
# !aws s3 sync --no-sign-request s3://openneuro.org/ds001499 {dataset_path} --exclude "*" --include "derivatives/spm*"
# Out:
# download: s3://openneuro.org/ds001499/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHRSC.nii.gz to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHRSC.nii.gz
# download: s3://openneuro.org/ds001499/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHLOC.nii.gz to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHLOC.nii.gz
# download: s3://openneuro.org/ds001499/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHEarlyVis.nii.gz to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHEarlyVis.nii.gz
# download: s3://openneuro.org/ds001499/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHOPA.nii.gz to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/spm/sub-CSI1/sub-CSI1_mask-LHOPA.nii.gz
# ...

# %% [markdown]
# ## Freesurfer Data

# %%
# !aws s3 sync --no-sign-request s3://openneuro.org/ds001499 {dataset_path} --exclude "*" --include "derivatives/freesurfer*"
# Out:
# download: s3://openneuro.org/ds001499/derivatives/freesurfer/fsaverage/label/Yeo_Brainmap_fsaverage_README to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/freesurfer/fsaverage/label/Yeo_Brainmap_fsaverage_README
# download: s3://openneuro.org/ds001499/derivatives/freesurfer/fsaverage/label/lh.BA1_exvivo.thresh.label to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/freesurfer/fsaverage/label/lh.BA1_exvivo.thresh.label
# download: s3://openneuro.org/ds001499/derivatives/freesurfer/fsaverage/label/lh.BA3a_exvivo.thresh.label to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/freesurfer/fsaverage/label/lh.BA3a_exvivo.thresh.label
# download: s3://openneuro.org/ds001499/derivatives/freesurfer/fsaverage/label/lh.BA2_exvivo.thresh.label to ../../../../../babbage/b/nobackup/nblancha/public-datasets/bold5000/derivatives/freesurfer/fsaverage/label/lh.BA2_exvivo.thresh.label
# ...
